# %%
import pymysql as py 
print('done')
# Out:
# done

# %%
# pip install PyMySQL
# Out:
# Requirement already satisfied: PyMySQL in c:\users\inder\anaconda3\lib\site-packages (1.1.1)Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql as py 
print('done')
# Out:
# done

# %%
conn = py.connect(user = 'root', 
           password='ind3rpal0117',
           host = 'localhost',
          autocommit = True)

print('connection created successfully!!')
print('done')
# Out:
# connection created successfully!!
# done

# %%
# cursor

# %%
cur= conn.cursor()
print('done')
# Out:
# done

# %%
# create database using pyhton

# %%
query = '''create database IITM_day5;'''

cur.execute(query)
print('done')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[7], line 3
#       1 query = '''create database IITM_day5;'''
# ----> 3 cur.execute(query)
#       4 print('done')
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File ~\anaconda3\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# ProgrammingError: (1007, "Can't create database 'iitm_day5'; database exists")

# %%
query = 'USE IITM_day5;'
cur.execute(query)
print('done')
# Out:
# done

# %%
query = '''create table student_details
(
SID int not null,
student_name varchar(50),
course varchar(50),
Address varchar(50),
scholarship float
);'''

cur.execute(query)
print('done')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[9], line 10
#       1 query = '''create table student_details
#       2 (
#       3 SID int not null,
#    (...)
#       7 scholarship float
#       8 );'''
# ---> 10 cur.execute(query)
#      11 print('done')
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File ~\anaconda3\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (1050, "Table 'student_details' already exists")

# %%
query = '''insert into student_details
values
(101,"hrideay","BCA","DELHI JANAKPURI",5000),
(102,"sahib","BCA","WEST DELHI",4500)
(105,"BHAVY","BCA","DELHI PATEL NAGAR",5500);
'''
cur.execute(query)
print('done')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[10], line 7
#       1 query = '''insert into student_details
#       2 values
#       3 (101,"hrideay","BCA","DELHI JANAKPURI",5000),
#       4 (102,"sahib","BCA","WEST DELHI",4500)
#       5 (105,"BHAVY","BCA","DELHI PATEL NAGAR",5500);
#       6 '''
# ----> 7 cur.execute(query)
#       8 print('done')
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File ~\anaconda3\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# ProgrammingError: (1064, 'You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near \'(105,"BHAVY","BCA","DELHI PATEL NAGAR",5500)\' at line 5')

# %%
query = '''insert into student_details
values
(102,"sahib","BCA","WEST DELHI",4500);
'''
cur.execute(query)
print('done')
# Out:
# done

# %%
sid = int(input('Enter Roll no/SID: '))
name = input('Enter your name: ')
course = input('Enter your course: ')
address = input('Enter your address: ')
scholarship = float(input('Enter your scholarship in RS: '))

q = f'''insert into student_details values
({sid},"{name}","{course}","{address}",{scholarship});'''

cur.execute(q)
print('done')
# Out:
# Enter Roll no/SID:  104
# Enter your name:  montu
# Enter your course:  mca
# Enter your address:  punjabi bagh
# Enter your scholarship in RS:  4455
# done

# %%
n = 3
for i in range(n):
    sid = int(input('Enter Roll no/SID: '))
    name = input('Enter your name: ')
    course = input('Enter your course: ')
    address = input('Enter your address: ')
    scholarship = float(input('Enter your scholarship in RS: '))
    
    q = f'''insert into student_details values
    ({sid},"{name}","{course}","{address}",{scholarship});'''
    
    cur.execute(q)
print('record inserted successfully')
print('done')
# Out:
# Enter Roll no/SID:  101
# Enter your name:  nncd
# Enter your course:  dfg4re
# Enter your address:  reger
# Enter your scholarship in RS:  55
# Enter Roll no/SID:  55
# Enter your name:  ergreg
# Enter your course:  ger
# Enter your address:  rgeg
# Enter your scholarship in RS:  44
# Enter Roll no/SID:  44
# Enter your name:  gre
# Enter your course:  reg
# Enter your address:  rgre
# Enter your scholarship in RS:  55
# record inserted successfully
# done

# %%
query = '''select * from student_details;'''
cur.execute(query)


records = cur.fetchall()

all_columns = []
for i in cur.description:
 all_columns.append(i[0])

import pandas as pd
df = pd.DataFrame(records,columns=all_columns)
df
# Out:
#     SID student_name  course            Address  scholarship
# 0   101      hrideay     BCA    DELHI JANAKPURI       5000.0
# 1   105        BHAVY     BCA  DELHI PATEL NAGAR       5500.0
# 2   102        sahib     BCA         WEST DELHI       4500.0
# 3   102        sahib     BCA         WEST DELHI       4500.0
# 4   104        montu     mca       punjabi bagh       4455.0
# 5   106         jay'     mba            patiala       4500.0
# 6   108        jyoti    bca'             punjab       4455.0
# 7   105        jeetu     bba           inderlok       4855.0
# 8   101         nncd  dfg4re              reger         55.0
# 9    55       ergreg     ger               rgeg         44.0
# 10   44          gre     reg               rgre         55.0

# %%
# all_columns = []
# for i in cur.description:
 # all_columns.append(i[0])
# df = pd.DataFrame(records,columns=all_columns) to use data frsme\

# %%
def show_records(db,table):

    query = f'''select * from {db}.{table};'''
    cur.execute(query)
    
    records = cur.fetchall()
    
    all_columns = []
    for i in cur.description:
     all_columns.append(i[0])
    
    import pandas as pd
    df = pd.DataFrame(records,columns=all_columns)
    return df

# %%
show_records('iitm_day5','student_details')
# Out:
#     SID student_name  course            Address  scholarship
# 0   101      hrideay     BCA    DELHI JANAKPURI       5000.0
# 1   105        BHAVY     BCA  DELHI PATEL NAGAR       5500.0
# 2   102        sahib     BCA         WEST DELHI       4500.0
# 3   102        sahib     BCA         WEST DELHI       4500.0
# 4   104        montu     mca       punjabi bagh       4455.0
# 5   106         jay'     mba            patiala       4500.0
# 6   108        jyoti    bca'             punjab       4455.0
# 7   105        jeetu     bba           inderlok       4855.0
# 8   101         nncd  dfg4re              reger         55.0
# 9    55       ergreg     ger               rgeg         44.0
# 10   44          gre     reg               rgre         55.0

# %%
show_records('iitm_db','sample_superstore')
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9689    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9690    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9691    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9692    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9693    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9689    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9690    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9691    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9692    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9693    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9689  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9690  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9691  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9692  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9693  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9689                             Ultra Door Pull Handle   25.2480         3
# 9690  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9691                              Aastra 57i VoIP phone  258.5760         2
# 9692  It's Hot Message Books with Stickers, 2 3/4" x...   29.6000         4
# 9693  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9689      0.20    4.1028
# 9690      0.00   15.6332
# 9691      0.20   19.3932
# 9692      0.00   13.3200
# 9693      0.00   72.9480
#
# [9694 rows x 21 columns]

# %%
conn.close()
print('done')
# Out:
# done
